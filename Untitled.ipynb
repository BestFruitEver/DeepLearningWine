# %%
# Installation des dépendances pour installer FastAI
# !pip install -Uqq fastbook
import fastbook
fastbook.setup_book()
# Out:
# C:\Users\romai\AppData\Local\Programs\Python\Python39\lib\site-packages\fastbook\__init__.py:19: UserWarning: Missing `graphviz` - please run `conda install fastbook`
#   except ModuleNotFoundError: warn("Missing `graphviz` - please run `conda install fastbook`")
